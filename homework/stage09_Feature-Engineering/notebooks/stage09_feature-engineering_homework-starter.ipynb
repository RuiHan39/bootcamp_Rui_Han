# %% [markdown]
# # Stage 09 — Homework Starter Notebook
#
# In the lecture, we learned how to create engineered features. Now it’s your turn to apply those ideas to your own project data.

# %%
import pandas as pd
import numpy as np

file_path = r"C:\Users\Yvaine\bootcamp_Rui_Han\homework\stage09_Feature-Engineering\data\personal_finance_tracker_dataset.csv"
df = pd.read_csv(file_path)

print("Shape:", df.shape)          # (行数, 列数)
print("\nColumns:\n", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())

df.head()
# Out:
# Shape: (3000, 24)
#
# Columns:
#  ['date', 'user_id', 'monthly_income', 'monthly_expense', 'budget_goal', 'financial_scenario', 'credit_score', 'debt_to_income_ratio', 'loan_payment', 'investment_amount', 'subscription_services', 'emergency_fund', 'transaction_count', 'fraud_flag', 'discretionary_spending', 'essential_spending', 'income_type', 'rent_or_mortgage', 'category', 'cash_flow_status', 'financial_advice_score', 'financial_stress_level', 'actual_savings', 'savings_goal_met']
#
# Dtypes:
#  date                       object
# user_id                     int64
# monthly_income            float64
# monthly_expense           float64
# budget_goal               float64
# financial_scenario         object
# credit_score                int64
# debt_to_income_ratio      float64
# loan_payment              float64
# investment_amount         float64
# subscription_services       int64
# emergency_fund            float64
# transaction_count           int64
# ...

# %% [markdown]
# ## TODO: Implement at least 2 engineered features here

# %%
df['saving_rate'] = (df['monthly_income']-df['monthly_expense'])/df['monthly_income']

# %% [markdown]
# Rationale: "Compute the monthly saving-to-income ratio to gauge students’ saving habits."

# %% [markdown]
# ### Rationale for Feature 1
# Explain why this feature may help a model. Reference your EDA.

# %%
df['rolling_expense_mean'] = df['monthly_expense'].rolling(3).mean()

# %% [markdown]
# ### Rationale for Feature 2
# Investigate the trend in spending changes over three months.
